# %%
people = ['Ann', 'Brandon', 'Chen', 'David', 'Emily', 'Farron',
          'Gagan', 'Hari', 'Julio', 'Kat']
age = [21, 12, 32, 45, 18, 28, 52, 5, 40, 48, 15]
weight = [70, 65, 72, 68, 75, 80, 76, 71, 74, 69]
height = [55, 35, 77, 68, 70, 60, 18, 65, 82, 48]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(weight,height)
plt.title("relation betweeen weight and height of patients")
plt.ylabel("heights in ,meters")
plt.xlabel("weight of patients in kgs")
plt.show()

# %%
plt.figure(figsize=(12, 4))
plt.title("People's weight in kgs", fontsize=16, fontstyle='italic')

# Main plot function 'bar'
plt.bar(x=people, height=weight, width=0.6, color='orange', edgecolor='k', alpha=0.6)

plt.xlabel("People", fontsize=15)
plt.xticks(fontsize=14, rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)", fontsize=15)

plt.show()

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs", fontsize=16,
          fontstyle='italic')
#main plot function 'bar'
plt.bar(x=people,height=weight, width=0.6,
        color='orange',edgecolor='k',alpha=0.6)

plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("weight (in kgs)",fontsize=15)
# Out:
# Text(0, 0.5, 'weight (in kgs)')

# %%
import numpy as np

plt.figure(figsize=(7,5))

#Main plot function 'hist'

plt.hist(weight, color='red', edgecolor='k', alpha=0.75,bins=5)

plt.title("Histogram of patient weight", fontsize=18)

plt.xlabel("Weight in kgs", fontsize=15)

plt.xticks(fontsize=15)

plt.yticks(fontsize=15)

plt.show()

# %%
import pandas as ps
a= ps.read_csv("sem2.csv")
print (a.head)
# Out:
# <bound method NDFrame.head of      People  Age  Height  Weight
# 0     rishi   18     143      45
# 1  srikanth   19     132      50
# 2   amrutha   17     123      80
# 3  ashwitha   18     100      65
# 4  madhavan   15      80      76
# 5  samhitha   18     100      54>

# %%
print (a.tail)
# Out:
# <bound method NDFrame.tail of      People  Age  Height  Weight
# 0     rishi   18     143      45
# 1  srikanth   19     132      50
# 2   amrutha   17     123      80
# 3  ashwitha   18     100      65
# 4  madhavan   15      80      76
# 5  samhitha   18     100      54>

# %%
x=['age']
y=['height']
import matplotlib.pyplot as plt
plt.scatter(weight,height)
plt.title("relation betweeen weight and height of patients")
plt.ylabel("heights in ,meters")
plt.xlabel("weight of patients in kgs")
plt.show()

# %%
plt.figure(figsize=(12, 4))
plt.title("People's weight in kgs", fontsize=16, fontstyle='italic')

# Main plot function 'bar'
plt.bar(x=people, height=weight, width=0.6, color='orange', edgecolor='k', alpha=0.6)

plt.xlabel("People", fontsize=15)
plt.xticks(fontsize=14, rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)", fontsize=15)

plt.show()

# %%
import pandas as ps
a= ps.read_excel("sem2.xlsx")
print (a.head)
# Out:
# <bound method NDFrame.head of      People  Age  Height  Weight
# 0     rishi   18     143      45
# 1  srikanth   19     132      50
# 2   amrutha   17     123      80
# 3  ashwitha   18     100      65
# 4  madhavan   15      80      76
# 5  samhitha   18     100      54>

# %%
print (a.tail)
x=['age']
y=['height']
import matplotlib.pyplot as plt
plt.scatter(weight,height)
plt.title("relation betweeen weight and height of patients")
plt.ylabel("heights in ,meters")
plt.xlabel("weight of patients in kgs")
plt.show()
plt.figure(figsize=(12, 4))
plt.title("People's weight in kgs", fontsize=16, fontstyle='italic')

# Main plot function 'bar'
plt.bar(x=people, height=weight, width=0.6, color='orange', edgecolor='k', alpha=0.6)

plt.xlabel("People", fontsize=15)
plt.xticks(fontsize=14, rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)", fontsize=15)

plt.show()
# Out:
# <bound method NDFrame.tail of      People  Age  Height  Weight
# 0     rishi   18     143      45
# 1  srikanth   19     132      50
# 2   amrutha   17     123      80
# 3  ashwitha   18     100      65
# 4  madhavan   15      80      76
# 5  samhitha   18     100      54>

# %%
import pandas as ps
a= ps.read_csv("sem2.tsv", sep='\t')
print (a.head)
# Out:
# <bound method NDFrame.head of      People  Age  Height  Weight
# 0     rishi   18     143      45
# 1  srikanth   19     132      50
# 2   amrutha   17     123      80
# 3  ashwitha   18     100      65
# 4  madhavan   15      80      76
# 5  samhitha   18     100      54>

# %%
print (a.tail)
x=['age']
y=['height']
import matplotlib.pyplot as plt
plt.scatter(weight,height)
plt.title("relation betweeen weight and height of patients")
plt.ylabel("heights in ,meters")
plt.xlabel("weight of patients in kgs")
plt.show()
plt.figure(figsize=(12, 4))
plt.title("People's weight in kgs", fontsize=16, fontstyle='italic')

# Main plot function 'bar'
plt.bar(x=people, height=weight, width=0.6, color='orange', edgecolor='k', alpha=0.6)

plt.xlabel("People", fontsize=15)
plt.xticks(fontsize=14, rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)", fontsize=15)

plt.show()
# Out:
# <bound method NDFrame.tail of      People  Age  Height  Weight
# 0     rishi   18     143      45
# 1  srikanth   19     132      50
# 2   amrutha   17     123      80
# 3  ashwitha   18     100      65
# 4  madhavan   15      80      76
# 5  samhitha   18     100      54>
